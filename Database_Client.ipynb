# %%
import mysql.connector as connector

# %%
connection = connector.connect(user = "root", password = "12345", db = "LittleLemonDB")

# %%
cursor = connection.cursor()

# %%
show_tables_query = "SHOW tables" 
cursor.execute(show_tables_query)

# %%
result = cursor.fetchall()

# %%
print(result)
# Out:
# [('booking',), ('customerdetails',), ('menu',), ('menuitems',), ('orderdeliverystatus',), ('orders',), ('ordersview',), ('staffdetails',)]

# %%
query = """ SELECT c.CustomerName, c.ContactNumber, c.Email, o.TotalCost 
from CustomerDetails as c INNER JOIN Orders as o 
ON c.CustomerID = o.CustomerID 
WHERE o.TotalCost > 60; """
cursor.execute(query)

# %%
result_1 = cursor.fetchall()
columns = cursor.column_names
print(columns)
for i in result_1:
    print (i)
# Out:
# ('CustomerName', 'ContactNumber', 'Email', 'TotalCost')
